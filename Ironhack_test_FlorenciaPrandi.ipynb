# %% [markdown]
# <a href="https://colab.research.google.com/github/FlorPrandi/nuclio-git-course/blob/main/Ironhack_test_FlorenciaPrandi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read the .csv
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ironhack/DA_test_Dataset.xlsx_-_data_(1).csv',
                   sep = ',', index_col = [0])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3292 entries, 0011t00000dX3JLAA0 to 0015J00000AQNrTQAX
# Data columns (total 51 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Course                                   3292 non-null   object
#  1   Format                                   3292 non-null   object
#  2   Start date                               3292 non-null   object
#  3   Age C                                    32 non-null     float64
#  4   Created Date                             3292 non-null   object
#  5   Close Date                               3292 non-null   int64
#  6   Lost Deal Reason C                       2933 non-null   object
#  7   Contact C                                3292 non-null   object
#  8   Is Won                                   3292 non-null   bool
#  9   Scholarship Name C                       2184 non-null   object
# ...

# %%
# Check the first 5 rows
dataset.head()
# Out:
#                    Course Format  Start date  Age C Created Date  Close Date  \
# ID
# 0011t00000dX3JLAA0     DA     PT  16/06/2020    NaN   27/02/2020       44124
# 0011t00000dx7kTAAQ     DA     PT  16/06/2020    NaN   10/12/2019       43867
# 0011t00000dxuRgAAI     WD     PT  16/06/2020    NaN   14/02/2020       43875
# 0011t00000dy9pvAAA     UX     FT  13/01/2020    NaN   23/06/2019       43717
# 0011t00000dynP9AAI     UX     PT  17/03/2020    NaN   22/01/2020       43852
#
#                        Lost Deal Reason C           Contact C  Is Won  \
# ID
# 0011t00000dX3JLAA0  Missed in application  0031t00000b5bBjAAI   False
# 0011t00000dx7kTAAQ                    NaN  0031t00000bYjevAAC    True
# 0011t00000dxuRgAAI  Missed in application  0031t00000ba7yBAAQ   False
# 0011t00000dy9pvAAA                    NaN  0031t00000bahk1AAA    True
# 0011t00000dynP9AAI  Missed in application  0031t00000cdPezAAE   False
#
# ...

# %%
# Check the last 5 rows
dataset.tail()
# Out:
#                    Course Format  Start date  Age C Created Date  Close Date  \
# ID
# 0015J00000AQEUYQA5     UX     FT  19/10/2020    NaN   29/09/2020       44109
# 0015J00000AQG9bQAH     UX     FT  19/10/2020    NaN   30/09/2020       44104
# 0015J00000AQHHOQA5     DA     FT  19/10/2020    NaN   30/09/2020       44104
# 0015J00000AQLHrQAP     UX     FT  19/10/2020    NaN   01/10/2020       44196
# 0015J00000AQNrTQAX     DA     FT  19/10/2020    NaN   01/10/2020       44196
#
#                             Lost Deal Reason C           Contact C  Is Won  \
# ID
# 0015J00000AQEUYQA5                         NaN  0035J000009gChIQAU    True
# 0015J00000AQG9bQAH  Can not afford the payment  0035J000009gEQ2QAM   False
# 0015J00000AQHHOQA5                     No time  0035J000009gFf2QAE   False
# 0015J00000AQLHrQAP  Can not afford the payment  0035J000009gJvCQAU   False
# 0015J00000AQNrTQAX       Missed in application  0035J000009gMm9QAE   False
#
# ...

# %%
# Check if there are duplicates (only 1)

len(dataset[dataset.duplicated()])
# Out:
# 1

# %%
# The row duplicated

dataset[dataset.duplicated(keep = False)]
# Out:
#                    Course Format  Start date  Age C Created Date  Close Date  \
# ID
# 0011t00001BIIqdAAH     WD     FT  29/06/2020    NaN   11/03/2020       44124
# 0011t00001BIIqdAAH     WD     FT  29/06/2020    NaN   11/03/2020       44124
#
#                        Lost Deal Reason C           Contact C  Is Won  \
# ID
# 0011t00001BIIqdAAH  Missed in application  0031t00001A4QHJAA3   False
# 0011t00001BIIqdAAH  Missed in application  0031t00001A4QHJAA3   False
#
#                    Scholarship Name C  ...  Ga Connector Last Click Medium C  \
# ID                                     ...
# 0011t00001BIIqdAAH             Vinted  ...                               NaN
# 0011t00001BIIqdAAH             Vinted  ...                               NaN
#
#                     Ga Connector Last Click Source C  \
# ID
# 0011t00001BIIqdAAH                               NaN
# 0011t00001BIIqdAAH                               NaN
#
# ...

# %%
# Create a copy in order to delete the duplicate

dataset2 = dataset.copy()

# %%
# Delete the duplicates

dataset2.drop_duplicates(inplace = True)

# %%
dataset2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3291 entries, 0011t00000dX3JLAA0 to 0015J00000AQNrTQAX
# Data columns (total 51 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Course                                   3291 non-null   object
#  1   Format                                   3291 non-null   object
#  2   Start date                               3291 non-null   object
#  3   Age C                                    32 non-null     float64
#  4   Created Date                             3291 non-null   object
#  5   Close Date                               3291 non-null   int64
#  6   Lost Deal Reason C                       2932 non-null   object
#  7   Contact C                                3291 non-null   object
#  8   Is Won                                   3291 non-null   bool
#  9   Scholarship Name C                       2183 non-null   object
# ...

# %%
# See that we have huge amount of Loss application 2950 with the reason most common "Missed in application", followed by a "No replay" in notes

dataset2.describe(include=['object','boolean']).T
# Out:
#                                         count unique  \
# Course                                   3291      3
# Format                                   3291      2
# Start date                               3291     12
# Created Date                             3291    388
# Lost Deal Reason C                       2932     19
# Contact C                                3291   3208
# Is Won                                   3291      2
# Scholarship Name C                       2183     10
# Drop                                     3291      2
# Discount Name C                           405      9
# Drop Reason C                              18      7
# Lost Reason Notes C                       486    257
# First Touch Point Type C                  672      1
# Cov ID Discount C                        3290      2
# Financing Options C                        33      3
# Need Financing C                          200      2
# Is Closed                                3291      2
# ...

# %%
plt.figure(figsize = (15,5))
sns.countplot(dataset2['Is Won'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (15,5))
sns.countplot(dataset2['Drop'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (50,10))
sns.countplot(dataset2['Lost Deal Reason C'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
